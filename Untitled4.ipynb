# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense, Dropout, 
                                     GlobalAveragePooling2D, concatenate, Input, BatchNormalization)
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
# 1. Load and preprocess images
def load_data(data_dir, img_size=224):
    classes = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
    X, y = [], []

    for label in classes:
        path = os.path.join(data_dir, label)
        for img_file in os.listdir(path):
            img_path = os.path.join(path, img_file)
            try:
                img = cv2.imread(img_path, cv2.IMREAD_COLOR)
                if img is not None:
                    img = cv2.resize(img, (img_size, img_size))
                    X.append(img)
                    y.append(classes.index(label))  # Convert label to an index
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")

    X = np.array(X) / 255.0  # Normalize images
    y = np.array(y)
    return X, y

# %%
# 2. Load training and testing data
train_dir = "E:\\college\\grad project\\integrated\\training"  # Set your training dataset directory
test_dir = "E:\\college\\grad project\\integrated\\testing"    # Set your testing dataset directory

X_train, y_train = load_data(train_dir)
X_test, y_test = load_data(test_dir)

# %%
# 3. Encode labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# 4. Define hybrid model (CNN + ResNet50V2)
def create_hybrid_model(input_shape=(224, 224, 3)):
    # CNN branch
    cnn_input = Input(shape=input_shape)
    x1 = Conv2D(32, (3, 3), activation='relu')(cnn_input)
    x1 = BatchNormalization()(x1)
    x1 = MaxPooling2D(pool_size=(2, 2))(x1)
    x1 = Conv2D(64, (3, 3), activation='relu')(x1)
    x1 = BatchNormalization()(x1)
    x1 = MaxPooling2D(pool_size=(2, 2))(x1)
    x1 = Flatten()(x1)

    # ResNet50V2 branch
    resnet = ResNet50V2(weights='imagenet', include_top=False, input_shape=input_shape)
    for layer in resnet.layers[:-10]:  # Unfreeze the last 10 layers for fine-tuning
        layer.trainable = False
    x2 = resnet.output
    x2 = GlobalAveragePooling2D()(x2)

    # Combine CNN and ResNet branches
    combined = concatenate([x1, x2])
    combined = Dense(256, activation='relu')(combined)
    combined = Dropout(0.5)(combined)
    output = Dense(4, activation='softmax')(combined)  # 4 classes

    model = Model(inputs=[cnn_input, resnet.input], outputs=output)
    model.compile(optimizer=Adam(learning_rate=1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

hybrid_model = create_hybrid_model()

# %%
# 5. Data augmentation
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    brightness_range=[0.8, 1.2],
    shear_range=0.2,
    fill_mode='nearest'
)
datagen.fit(X_train)

# %%
# Custom generator to yield two inputs for the model
def custom_data_generator(datagen, X, y, batch_size):
    while True:
        for X_batch, y_batch in datagen.flow(X, y, batch_size=batch_size):
            # Yielding a tuple of two identical inputs and the labels
            yield (X_batch, X_batch), y_batch  # Tuple format

# %%
# 6. Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# %%
# 7. Train hybrid model using the custom data generator
history = hybrid_model.fit(
    custom_data_generator(datagen, X_train, y_train_encoded, batch_size=32),
    steps_per_epoch=len(X_train) // 32,
    validation_data=([X_test, X_test], y_test_encoded),
    epochs=20,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/20
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 613s 2s/step - accuracy: 0.2745 - loss: 5.0541 - val_accuracy: 0.2534 - val_loss: 173.7799 - learning_rate: 1.0000e-04
# Epoch 2/20
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 604s 2s/step - accuracy: 0.2806 - loss: 1.8206 - val_accuracy: 0.2469 - val_loss: 2915.9297 - learning_rate: 1.0000e-04
# Epoch 3/20
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 646s 2s/step - accuracy: 0.2728 - loss: 1.4994 - val_accuracy: 0.2469 - val_loss: 3741.1365 - learning_rate: 1.0000e-04
# Epoch 4/20
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 633s 2s/step - accuracy: 0.2829 - loss: 1.4270 - val_accuracy: 0.2469 - val_loss: 1208.5653 - learning_rate: 1.0000e-04
# Epoch 5/20
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 4134s 11s/step - accuracy: 0.2860 - loss: 1.3702 - val_accuracy: 0.2469 - val_loss: 1329.3771 - learning_rate: 2.0000e-05
# Epoch 6/20
#  46/364 ━━━━━━━━━━━━━━━━━━━━ 8:21 2s/step - accuracy: 0.2903 - loss: 1.3783
# ---------------------------------------------------------------------------
# ...

# %%
# 8. Evaluate the model
loss, accuracy = hybrid_model.evaluate([X_test, X_test], y_test_encoded)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")

# %%
# Classification report
y_pred = np.argmax(hybrid_model.predict([X_test, X_test]), axis=1)
print(classification_report(y_test_encoded, y_pred, target_names=label_encoder.classes_))

# %%
# Confusion matrix
display = ConfusionMatrixDisplay.from_predictions(y_test_encoded, y_pred, display_labels=label_encoder.classes_)
plt.show()

# %%
# 9. Save the model
model_path = "hybrid_model.h5"
hybrid_model.save(model_path)
print(f"Model saved to {model_path}")
